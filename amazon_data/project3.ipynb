# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("sales_data.csv")
data.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  18-10-2014  686800706  31-10-2014        8446      437.20
# 1              M  07-11-2011  185941302  08-12-2011        3018      154.06
# 2              C  31-10-2016  246222341  09-12-2016        1517      255.28
# 3              C  10-04-2010  161442649  12-05-2010        3322      205.70
# 4              H  16-08-2011  645713555  31-08-2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
data.dtypes
# Out:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
data.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          1000 non-null   object
#  1   Country         1000 non-null   object
#  2   Item Type       1000 non-null   object
#  3   Sales Channel   1000 non-null   object
#  4   Order Priority  1000 non-null   object
#  5   Order Date      1000 non-null   object
#  6   Order ID        1000 non-null   int64
#  7   Ship Date       1000 non-null   object
#  8   Units Sold      1000 non-null   int64
#  9   Unit Price      1000 non-null   float64
#  10  Unit Cost       1000 non-null   float64
#  11  Total Revenue   1000 non-null   float64
#  12  Total Cost      1000 non-null   float64
#  13  Total Profit    1000 non-null   float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 109.5+ KB

# %%
data.shape
# Out:
# (1000, 14)

# %%
data[["Total Revenue","Total Profit"]]
# Out:
#      Total Revenue  Total Profit
# 0       3692591.20    1468506.02
# 1        464953.08     190526.34
# 2        387259.76     145419.62
# 3        683335.40     294295.98
# 4         91853.85      23726.45
# ..             ...           ...
# 995      995431.92     359733.36
# 996       73520.64      27607.68
# 997     1472197.36     603270.28
# 998     6549714.27    1624319.73
# 999      725709.60     312545.52
#
# [1000 rows x 2 columns]

# %%
np.corrcoef(data["Total Revenue"],data["Total Profit"])
# Out:
# array([[1.        , 0.88142907],
#        [0.88142907, 1.        ]])

# %%
data.set_index('Order ID',inplace=True)

# %%
data.head()
# Out:
#                                  Region Country   Item Type Sales Channel  \
# Order ID
# 686800706  Middle East and North Africa   Libya   Cosmetics       Offline
# 185941302                 North America  Canada  Vegetables        Online
# 246222341  Middle East and North Africa   Libya   Baby Food       Offline
# 161442649                          Asia   Japan      Cereal       Offline
# 645713555            Sub-Saharan Africa    Chad      Fruits       Offline
#
#           Order Priority  Order Date   Ship Date  Units Sold  Unit Price  \
# Order ID
# 686800706              M  18-10-2014  31-10-2014        8446      437.20
# 185941302              M  07-11-2011  08-12-2011        3018      154.06
# 246222341              C  31-10-2016  09-12-2016        1517      255.28
# 161442649              C  10-04-2010  12-05-2010        3322      205.70
# 645713555              H  16-08-2011  31-08-2011        9845        9.33
#
# ...

# %%
data = data[["Order Date","Order Priority","Ship Date","Item Type","Region","Country","Sales Channel","Units Sold","Unit Price","Unit Cost","Total Revenue","Total Cost","Total Profit"]]

# %%
data
# Out:
#            Order Date Order Priority   Ship Date   Item Type  \
# Order ID
# 686800706  18-10-2014              M  31-10-2014   Cosmetics
# 185941302  07-11-2011              M  08-12-2011  Vegetables
# 246222341  31-10-2016              C  09-12-2016   Baby Food
# 161442649  10-04-2010              C  12-05-2010      Cereal
# 645713555  16-08-2011              H  31-08-2011      Fruits
# ...               ...            ...         ...         ...
# 534085166  18-04-2010              C  25-04-2010      Snacks
# 590768182  01-08-2011              H  07-09-2011   Baby Food
# 524363124  12-05-2011              C  28-06-2011  Vegetables
# 289606320  25-01-2016              L  14-02-2016   Household
# 811546599  10-04-2014              C  08-05-2014      Cereal
#
#                                  Region               Country Sales Channel  \
# Order ID
# 686800706  Middle East and North Africa                 Libya       Offline
# ...

# %%
data.describe()
# Out:
#         Units Sold  Unit Price    Unit Cost  Total Revenue    Total Cost  \
# count  1000.000000  1000.00000  1000.000000   1.000000e+03  1.000000e+03
# mean   5053.988000   262.10684   184.965110   1.327322e+06  9.361192e+05
# std    2901.375317   216.02106   175.289311   1.486515e+06  1.162571e+06
# min      13.000000     9.33000     6.920000   2.043250e+03  1.416750e+03
# 25%    2420.250000    81.73000    56.670000   2.811919e+05  1.649319e+05
# 50%    5184.000000   154.06000    97.440000   7.549392e+05  4.647261e+05
# 75%    7536.750000   421.89000   263.330000   1.733503e+06  1.141750e+06
# max    9998.000000   668.27000   524.960000   6.617210e+06  5.204978e+06
#
#        Total Profit
# count  1.000000e+03
# mean   3.912026e+05
# std    3.836402e+05
# min    5.326100e+02
# 25%    9.837612e+04
# 50%    2.772260e+05
# 75%    5.484568e+05
# max    1.726181e+06

# %%
data.cov(numeric_only = True)
# Out:
#                  Units Sold    Unit Price     Unit Cost  Total Revenue  \
# Units Sold     8.417979e+06  2.639656e+03  1.309092e+03   2.276995e+09
# Unit Price     2.639656e+03  4.666510e+04  3.736388e+04   2.346579e+08
# Unit Cost      1.309092e+03  3.736388e+04  3.072634e+04   1.870891e+08
# Total Revenue  2.276995e+09  2.346579e+08  1.870891e+08   2.209726e+12
# Total Cost     1.618097e+09  1.872342e+08  1.535891e+08   1.707058e+12
# Total Profit   6.588980e+08  4.742364e+07  3.350001e+07   5.026673e+11
#
#                  Total Cost  Total Profit
# Units Sold     1.618097e+09  6.588980e+08
# Unit Price     1.872342e+08  4.742364e+07
# Unit Cost      1.535891e+08  3.350001e+07
# Total Revenue  1.707058e+12  5.026673e+11
# Total Cost     1.351571e+12  3.554875e+11
# Total Profit   3.554875e+11  1.471798e+11

# %%
data.corr(numeric_only=True)
# Out:
#                Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# Units Sold       1.000000    0.004212   0.002574       0.527945    0.479713
# Unit Price       0.004212    1.000000   0.986735       0.730752    0.745538
# Unit Cost        0.002574    0.986735   1.000000       0.717999    0.753678
# Total Revenue    0.527945    0.730752   0.717999       1.000000    0.987779
# Total Cost       0.479713    0.745538   0.753678       0.987779    1.000000
# Total Profit     0.591957    0.572235   0.498156       0.881429    0.797041
#
#                Total Profit
# Units Sold         0.591957
# Unit Price         0.572235
# Unit Cost          0.498156
# Total Revenue      0.881429
# Total Cost         0.797041
# Total Profit       1.000000

# %% [markdown]
# __The high value of Pearson correlation coefficient between Total Revenue and Total Profit indicates that these two variables are closely related to each other.__

# %% [markdown]
# __If revenue generated is high, then more profit will be generated and vice versa.__

# %%
data["Total Profit"].mean()
# Out:
# 391202.61155999993

# %% [markdown]
# __At an average, the profit generated for a product is ₹391202.611___

# %%
data["Total Profit"].max()
# Out:
# 1726181.36

# %%
data["Total Profit"].min()
# Out:
# 532.61

# %% [markdown]
# __Maximum and minimum profit generated are ₹ 1726181.36 and ₹ 532.61 respectively.__

# %%
data["Total Profit"].var(numeric_only = True)         #for find the varience from mean value
# Out:
# 147179792210.28598

# %% [markdown]
# ## Let's study total revenue

# %%
data["Total Revenue"].describe()
# Out:
# count    1.000000e+03
# mean     1.327322e+06
# std      1.486515e+06
# min      2.043250e+03
# 25%      2.811919e+05
# 50%      7.549392e+05
# 75%      1.733503e+06
# max      6.617210e+06
# Name: Total Revenue, dtype: float64

# %%
data["Total Revenue"].median()
# Out:
# 754939.1799999999

# %%
data["Total Revenue"].min()
# Out:
# 2043.25

# %%
data["Total Revenue"].max()
# Out:
# 6617209.54

# %% [markdown]
# __Maximum and minimum revenue generated by the product are ₹
# 6617209.54 and ₹
# 2043.256.
# Revenue has very high variability in it's distribution. The median revenue generated is 6617209.5436.__

# %%
sns.relplot(data,x='Total Profit',y ='Total Revenue',hue="Sales Channel",palette="viridis")

# %% [markdown]
# __The scatter plot also suggests that total profit and total revenue are directly proportional to each other.__

# %%
sns.histplot(data,x="Total Revenue",kde = True,bins = 10)
# Out:
# <Axes: xlabel='Total Revenue', ylabel='Count'>

# %%
data.head(2)
# Out:
#            Order Date Order Priority   Ship Date   Item Type  \
# Order ID
# 686800706  18-10-2014              M  31-10-2014   Cosmetics
# 185941302  07-11-2011              M  08-12-2011  Vegetables
#
#                                  Region Country Sales Channel  Units Sold  \
# Order ID
# 686800706  Middle East and North Africa   Libya       Offline        8446
# 185941302                 North America  Canada        Online        3018
#
#            Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# Order ID
# 686800706      437.20     263.33     3692591.20  2224085.18    1468506.02
# 185941302      154.06      90.93      464953.08   274426.74     190526.34

# %%
sns.histplot(data,x="Total Cost",kde = True,bins = 10)
# Out:
# <Axes: xlabel='Total Cost', ylabel='Count'>

# %%
data.corr(numeric_only = True)
# Out:
#                Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# Units Sold       1.000000    0.004212   0.002574       0.527945    0.479713
# Unit Price       0.004212    1.000000   0.986735       0.730752    0.745538
# Unit Cost        0.002574    0.986735   1.000000       0.717999    0.753678
# Total Revenue    0.527945    0.730752   0.717999       1.000000    0.987779
# Total Cost       0.479713    0.745538   0.753678       0.987779    1.000000
# Total Profit     0.591957    0.572235   0.498156       0.881429    0.797041
#
#                Total Profit
# Units Sold         0.591957
# Unit Price         0.572235
# Unit Cost          0.498156
# Total Revenue      0.881429
# Total Cost         0.797041
# Total Profit       1.000000

# %%
sns.scatterplot(data,x="Units Sold",y="Unit Cost")
# Out:
# <Axes: xlabel='Units Sold', ylabel='Unit Cost'>

# %% [markdown]
# __The above scatter plot implies that the between two variables 'Units Sold' and 'Unit Cost' no relation to some extent.__

# %%
sns.histplot(data,x='Unit Cost',kde=True)
# Out:
# <Axes: xlabel='Unit Cost', ylabel='Count'>

# %%
data["Unit Cost"].describe()
# Out:
# count    1000.000000
# mean      184.965110
# std       175.289311
# min         6.920000
# 25%        56.670000
# 50%        97.440000
# 75%       263.330000
# max       524.960000
# Name: Unit Cost, dtype: float64

# %%
data["Unit Cost"].median()
# Out:
# 97.44

# %%
data["Unit Cost"].var()
# Out:
# 30726.3427106986

# %% [markdown]
# __Maximum and minimum unit costs are ₹ 6.92 and ₹ 524.96 respectively. Average unit cost of a product is ₹ 184.965. The Unit Cost variable varies considerably throughout it's distribution. The median cost of a unit stands at ₹ 97.44.__

# %%
data.head(2)
# Out:
#            Order Date Order Priority   Ship Date   Item Type  \
# Order ID
# 686800706  18-10-2014              M  31-10-2014   Cosmetics
# 185941302  07-11-2011              M  08-12-2011  Vegetables
#
#                                  Region Country Sales Channel  Units Sold  \
# Order ID
# 686800706  Middle East and North Africa   Libya       Offline        8446
# 185941302                 North America  Canada        Online        3018
#
#            Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# Order ID
# 686800706      437.20     263.33     3692591.20  2224085.18    1468506.02
# 185941302      154.06      90.93      464953.08   274426.74     190526.34

# %%
plt.stackplot(data['Unit Price'],data['Total Profit'],color="pink")
plt.ylabel('Total Profit')
plt.xlabel('Unit Price')
# Out:
# Text(0.5, 0, 'Unit Price')

# %% [markdown]
# __Maximum profit has been generated in the unit price range of ₹400-₹500.__

# %%
plt.stackplot(data['Units Sold'],data['Total Profit'])
plt.ylabel('Total Profit')
plt.xlabel('Units Sold')
# Out:
# Text(0.5, 0, 'Units Sold')

# %% [markdown]
# __Maximum profit has been generated when the number of units sold were between 8000 and 10000 i.e. more the number of units sold, more will be the profit generated.__

# %%
plt.stackplot(data['Units Sold'],data['Total Cost'],color="skyblue")
plt.ylabel('Total Cost')
plt.xlabel('Units Sold')
# Out:
# Text(0.5, 0, 'Units Sold')

# %% [markdown]
# __Maximum cost has been generated when 8000-10000 units were sold.__

# %%
plt.stackplot(data['Units Sold'],data['Total Revenue'],color="grey")
plt.ylabel('Total Revenue')
plt.xlabel('Units Sold')
# Out:
# Text(0.5, 0, 'Units Sold')

# %% [markdown]
# __Maximum revenue has been generated when 8000-10000 units of a product were sold__

# %%
sns.pairplot(data,hue="Sales Channel")

# %%
data.head(2)
# Out:
#            Order Date Order Priority   Ship Date   Item Type  \
# Order ID
# 686800706  18-10-2014              M  31-10-2014   Cosmetics
# 185941302  07-11-2011              M  08-12-2011  Vegetables
#
#                                  Region Country Sales Channel  Units Sold  \
# Order ID
# 686800706  Middle East and North Africa   Libya       Offline        8446
# 185941302                 North America  Canada        Online        3018
#
#            Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# Order ID
# 686800706      437.20     263.33     3692591.20  2224085.18    1468506.02
# 185941302      154.06      90.93      464953.08   274426.74     190526.34

# %%
data['Item Type'].unique()
# Out:
# array(['Cosmetics', 'Vegetables', 'Baby Food', 'Cereal', 'Fruits',
#        'Clothes', 'Snacks', 'Household', 'Office Supplies', 'Beverages',
#        'Personal Care', 'Meat'], dtype=object)

# %%
gp = data.groupby("Item Type")["Total Revenue"].sum().plot(kind='bar',color=['green','orange','blue','red','purple','pink','yellow','brown','aqua','grey','seagreen','lightblue'])

# %% [markdown]
# __Maximum revenue has been earned from the items 'Office Supplies'.__

# %%
sns.barplot(data,x="Region",y="Total Profit",estimator='mean')
plt.xticks(rotation=90)                             #if estimator is mean
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Middle East and North Africa'),
#   Text(1, 0, 'North America'),
#   Text(2, 0, 'Asia'),
#   Text(3, 0, 'Sub-Saharan Africa'),
#   Text(4, 0, 'Europe'),
#   Text(5, 0, 'Central America and the Caribbean'),
#   Text(6, 0, 'Australia and Oceania')])

# %% [markdown]
# __average Profit is maximum in North America and Central America and the Caribbean, and minimum in Middle East and North Africa.__

# %%
data.groupby('Region')['Total Profit'].count().plot(kind='area',color=['purple','brown','blue','green'])
plt.xticks(rotation=90)
plt.ylabel('Total Profit')                #estimator is count plot
# Out:
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# __Maximum profit has been generated in the Sub-Saharan African and Europe region while minimum profit has been generated in the North American region.__

# %%
sns.barplot(data,x="Region",y="Total Cost")
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Middle East and North Africa'),
#   Text(1, 0, 'North America'),
#   Text(2, 0, 'Asia'),
#   Text(3, 0, 'Sub-Saharan Africa'),
#   Text(4, 0, 'Europe'),
#   Text(5, 0, 'Central America and the Caribbean'),
#   Text(6, 0, 'Australia and Oceania')])

# %% [markdown]
# __Cost of items is maximum in Central America and the Caribean, and minimum in Asia.__

# %%
data.corr(numeric_only=True)
# Out:
#                Units Sold  Unit Price  Unit Cost  Total Revenue  Total Cost  \
# Units Sold       1.000000    0.004212   0.002574       0.527945    0.479713
# Unit Price       0.004212    1.000000   0.986735       0.730752    0.745538
# Unit Cost        0.002574    0.986735   1.000000       0.717999    0.753678
# Total Revenue    0.527945    0.730752   0.717999       1.000000    0.987779
# Total Cost       0.479713    0.745538   0.753678       0.987779    1.000000
# Total Profit     0.591957    0.572235   0.498156       0.881429    0.797041
#
#                Total Profit
# Units Sold         0.591957
# Unit Price         0.572235
# Unit Cost          0.498156
# Total Revenue      0.881429
# Total Cost         0.797041
# Total Profit       1.000000

# %%
sns.heatmap(data.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# __From the above heatmap, we can infer that Total Cost is strongly related to Total Revenue, Unit Price,Unit Cost and Total Profit.__

# %% [markdown]
# __Units Sold and {Unit Price and Unit Cost} are completely independent. Number of units sold are independent of price charged per unit of a product and same with cost of a unit which is independent of units sold.__

# %%
sns.lineplot(data,x='Region',y='Total Cost',hue="Sales Channel",errorbar=None)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Middle East and North Africa'),
#   Text(1, 0, 'North America'),
#   Text(2, 0, 'Asia'),
#   Text(3, 0, 'Sub-Saharan Africa'),
#   Text(4, 0, 'Europe'),
#   Text(5, 0, 'Central America and the Caribbean'),
#   Text(6, 0, 'Australia and Oceania')])

# %% [markdown]
# __Products have been much more expensive in  Central America and the Caribean in comparison to other continents.__

# %%
plt.figure(figsize = (20,14))
sns.barplot(data,x='Country', y='Total Revenue',errorbar=None)
plt.xticks(rotation = 90)
plt.tick_params(axis='x',labelsize=7)

# %% [markdown]
# __Papua New Guinea is the country where maximum revenue has been generated.__

# %% [markdown]
# sns.lmplot(data,x='Unit Price',y='Total Cost',col='Sales Channel',hue='Unit Cost',aspect=1.5,height=7)

# %%
np.corrcoef(data['Unit Price'],data['Total Cost'])
# Out:
# array([[1.        , 0.74553801],
#        [0.74553801, 1.        ]])

# %% [markdown]
# __The high value of degree of correlation between 'Unit Price' and 'Total Cost' variables indicates that they are almost directly proportional to each other and highly dependent on each other.__

# %%
gp = data.groupby("Item Type")["Total Profit"].median().plot(kind='line',color='green',figsize=(8,4))
plt.ylabel("Total Profit")
# Out:
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# __Maximum profit genrated in Cosmatic__

# %%
data.groupby('Order Priority')['Total Revenue'].count().plot(kind='bar',color=['grey','blue','green','purple','brown'])
plt.xticks(rotation=0)
plt.ylabel('Total Revenue')
# Out:
# Text(0, 0.5, 'Total Revenue')

# %% [markdown]
# __Maximum number of revenues has been generated by the products having order priority 'L' while minimum revenues has been generated by 'H' priority products__

# %%
sns.barplot(data,x="Order Priority",y="Total Profit",estimator = 'sum')
# Out:
# <Axes: xlabel='Order Priority', ylabel='Total Profit'>

# %% [markdown]
# __Maximum profit has been generated by products having order priority 'L' while minimum profit has been obtained in case of 'H' priority product orders.__

# %%
data["Ship Date"] = pd.to_datetime(data["Ship Date"],dayfirst=True)
data["year"]=data["Ship Date"].dt.year
data.head(1)
# Out:
#            Order Date Order Priority  Ship Date  Item Type  \
# Order ID
# 686800706  18-10-2014              M 2014-10-31  Cosmetics
#
#                                  Region Country Sales Channel  Units Sold  \
# Order ID
# 686800706  Middle East and North Africa   Libya       Offline        8446
#
#            Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit  \
# Order ID
# 686800706       437.2     263.33      3692591.2  2224085.18    1468506.02
#
#            year
# Order ID
# 686800706  2014

# %%
plt.figure(figsize=(12,5))
sns.lineplot(data,x="year",y="Total Profit",estimator = 'sum',errorbar=None)
# Out:
# <Axes: xlabel='year', ylabel='Total Profit'>

# %% [markdown]
# __Maximum profit has been achieved during the year 2014.__

# %%
lables = data["Item Type"].value_counts().index
lables
# Out:
# Index(['Beverages', 'Vegetables', 'Office Supplies', 'Baby Food',
#        'Personal Care', 'Snacks', 'Cereal', 'Clothes', 'Meat', 'Household',
#        'Cosmetics', 'Fruits'],
#       dtype='object', name='Item Type')

# %%
sizes = data['Item Type'].value_counts().values
colors = ['grey','blue','red','lime','purple','brown','pink','seagreen','skyblue','yellow','magenta','orange']
sizes
# Out:
# array([101,  97,  89,  87,  87,  82,  79,  78,  78,  77,  75,  70],
#       dtype=int64)

# %%
plt.pie(sizes,labels=lables,colors=colors,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1dd350f9c70>,
# ...
#  [Text(1.0450891172191499, 0.3432036379033564, 'Beverages'),
#   Text(0.6493563166928925, 0.8878830857556868, 'Vegetables'),
#   Text(0.05181704640055825, 1.09877886478687, 'Office Supplies'),
#   Text(-0.5329547602909542, 0.962267750412125, 'Baby Food'),
#   Text(-0.955494680169572, 0.5450045102268857, 'Personal Care'),
#   Text(-1.0999131482721833, -0.013822671882601646, 'Snacks'),
#   Text(-0.9554946418993163, -0.5450045773217851, 'Cereal'),
#   Text(-0.5835622463403983, -0.9324457649891217, 'Clothes'),
#   Text(-0.07596595081721295, -1.0973737623601345, 'Meat'),
#   Text(0.4463578081715176, -1.0053679461193892, 'Household'),
#   Text(0.8584735047383398, -0.6877668512383188, 'Cosmetics'),
#   Text(1.0735084603744016, -0.23995746603217352, 'Fruits')],
#  [Text(0.5700486093922635, 0.18720198431092164, '10.1%'),
#   Text(0.3541943545597595, 0.4842998649576472, '9.7%'),
#   Text(0.028263843491213587, 0.5993339262473836, '8.9%'),
# ...

# %% [markdown]
# __Vegetables and Beverages are the most purchased.__

# %% [markdown]
# ## KDE Plot

# %%
sns.kdeplot(x='year',y='Units Sold',data=data,fill=True)
# Out:
# <Axes: xlabel='year', ylabel='Units Sold'>

# %%
sns.kdeplot(x='Ship Date',y='Total Cost',data=data,fill=True)
# Out:
# <Axes: xlabel='Ship Date', ylabel='Total Cost'>

# %%
sns.violinplot(data,x="Total Profit")
# Out:
# <Axes: xlabel='Total Profit'>

# %%
a= sns.FacetGrid(data,col="Sales Channel",hue='Unit Cost')
a.map(sns.scatterplot,'Unit Price','Total Cost')
