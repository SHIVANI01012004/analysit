# %% [markdown]
# ## Getting some basic information about datasets

# %%
import pandas as pd
data = pd.read_csv("netflixData2.csv")
data
# Out:
#      Show_id                          Title  \
# 0         s1                       (Un)Well
# 1         s2                         #Alive
# 2         s3  #AnneFrank - Parallel Stories
# 3         s4                       #blackAF
# 4         s5               #cats_the_mewvie
# ...      ...                            ...
# 5962   s5963                      الف مبروك
# 5963   s5964                   دفعة القاهرة
# 5964   s5965                           海的儿子
# 5965   s5966                        반드시 잡는다
# 5966   s5967            최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description  \
# 0     This docuseries takes a deep dive into the luc...
# 1     As a grisly virus rampages a city, a lone man ...
# 2     Through her diary, Anne Frank's story is retol...
# 3     Kenya Barris and his family navigate relations...
# 4     This pawesome documentary explores how our fel...
# ...                                                 ...
# ...

# %% [markdown]
# __for top 5 rows__

# %%
data.head()
# Out:
#   Show_id                          Title  \
# 0      s1                       (Un)Well
# 1      s2                         #Alive
# 2      s3  #AnneFrank - Parallel Stories
# 3      s4                       #blackAF
# 4      s5               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
#                                              Type  \
# 0                                      Reality TV
# 1  Horror Movies, International Movies, Thrillers
# ...

# %% [markdown]
# __For 5 bottom rows__

# %%
data.tail()
# Out:
#      Show_id                Title  \
# 5962   s5963            الف مبروك
# 5963   s5964         دفعة القاهرة
# 5964   s5965                 海的儿子
# 5965   s5966              반드시 잡는다
# 5966   s5967  최강전사 미니특공대 : 영웅의 탄생
#
#                                             Description           Director  \
# 5962  On his wedding day, an arrogant, greedy accoun...  Ahmed Nader Galal
# 5963  A group of women leaves Kuwait to attend unive...                NaN
# 5964  Two brothers start a new life in Singapore, wh...                NaN
# 5965  After people in his town start turning up dead...      Hong-seon Kim
# 5966  Miniforce, a special task force of elite range...      Young Jun Lee
#
#                                          Type  \
# 5962   Comedies, Dramas, International Movies
# 5963        International TV Shows, TV Dramas
# 5964        International TV Shows, TV Dramas
# 5965  Dramas, International Movies, Thrillers
# 5966                 Children & Family Movies
#
# ...

# %% [markdown]
# __To show the no of rows and column__

# %%
data.shape
# Out:
# (5967, 12)

# %% [markdown]
# __To show the total values in the dataset__

# %%
data.size
# Out:
# 71604

# %% [markdown]
# __To show each colum__

# %%
data.columns
# Out:
# Index(['Show_id', 'Title', 'Description', 'Director', 'Type', 'Cast',
#        'Country', 'Release Date', 'Rating', 'Duration', 'Category',
#        'Date Added'],
#       dtype='object')

# %% [markdown]
# __To show the data-type of each column__

# %%
data.dtypes
# Out:
# Show_id          object
# Title            object
# Description      object
# Director         object
# Type             object
# Cast             object
# Country          object
# Release Date    float64
# Rating           object
# Duration         object
# Category         object
# Date Added       object
# dtype: object

# %% [markdown]
# __To show indexes,column,data-types of each column , memory at once__

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5967 entries, 0 to 5966
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_id       5967 non-null   object
#  1   Title         5967 non-null   object
#  2   Description   5967 non-null   object
#  3   Director      3903 non-null   object
#  4   Type          5967 non-null   object
#  5   Cast          5437 non-null   object
#  6   Country       5408 non-null   object
#  7   Release Date  5964 non-null   float64
#  8   Rating        5963 non-null   object
#  9   Duration      5964 non-null   object
#  10  Category      5967 non-null   object
#  11  Date Added    4632 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 559.5+ KB

# %% [markdown]
# ## Is there any duplicates record in datasets ? If yes, then remove it...

# %%
data.head()
# Out:
#   Show_id                          Title  \
# 0      s1                       (Un)Well
# 1      s2                         #Alive
# 2      s3  #AnneFrank - Parallel Stories
# 3      s4                       #blackAF
# 4      s5               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
#                                              Type  \
# 0                                      Reality TV
# 1  Horror Movies, International Movies, Thrillers
# ...

# %%
data.shape
# Out:
# (5967, 12)

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5962    False
# 5963    False
# 5964    False
# 5965    False
# 5966    False
# Length: 5967, dtype: bool

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_id, Title, Description, Director, Type, Cast, Country, Release Date, Rating, Duration, Category, Date Added]
# Index: []

# %% [markdown]
# __From above analysis there is no duplicate data in this given datasets__

# %% [markdown]
# ## Is there any null value ? If yes then show with heat map

# %%
data.head()
# Out:
#   Show_id                          Title  \
# 0      s1                       (Un)Well
# 1      s2                         #Alive
# 2      s3  #AnneFrank - Parallel Stories
# 3      s4                       #blackAF
# 4      s5               #cats_the_mewvie
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
# 3  Kenya Barris and his family navigate relations...
# 4  This pawesome documentary explores how our fel...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
# 3                          NaN
# 4             Michael Margolis
#
#                                              Type  \
# 0                                      Reality TV
# 1  Horror Movies, International Movies, Thrillers
# ...

# %%
data.shape
# Out:
# (5967, 12)

# %% [markdown]
# __To show where null value is persent__

# %%
data.isnull()
# Out:
#       Show_id  Title  Description  Director   Type   Cast  Country  \
# 0       False  False        False      True  False   True    False
# 1       False  False        False     False  False  False    False
# 2       False  False        False     False  False  False    False
# 3       False  False        False      True  False  False    False
# 4       False  False        False     False  False   True    False
# ...       ...    ...          ...       ...    ...    ...      ...
# 5962    False  False        False     False  False  False    False
# 5963    False  False        False      True  False  False     True
# 5964    False  False        False      True  False  False     True
# 5965    False  False        False     False  False  False    False
# 5966    False  False        False     False  False  False     True
#
#       Release Date  Rating  Duration  Category  Date Added
# 0            False   False     False     False        True
# ...

# %% [markdown]
# __To show the count of null value in each column__

# %%
data.isnull().sum()
# Out:
# Show_id            0
# Title              0
# Description        0
# Director        2064
# Type               0
# Cast             530
# Country          559
# Release Date       3
# Rating             4
# Duration           3
# Category           0
# Date Added      1335
# dtype: int64

# %%
import seaborn as sns
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# __Q-1 For the house of cards , what is the show Id and who is the director of this show__

# %% [markdown]
# __Two method 1. isin()  2. str.contains()__

# %%
data[data['Title'].isin(['House of Cards'])][["Show_id","Title","Director"]]
# Out:
#      Show_id           Title Director
# 2130   s2131  House of Cards      NaN

# %%
data[data["Title"].str.contains("House of Cards")][["Show_id","Title","Director"]]
# Out:
#      Show_id           Title Director
# 2130   s2131  House of Cards      NaN

# %%
data = data.drop('Date',axis=1)

# %% [markdown]
# __Q-2 In which year heighest TV show and movies were released? Show with bar graph__

# %% [markdown]
# __1. Using value_counts() function__

# %%
fig = plt.figure(figsize =(15, 7))
data["Release Date"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Release Date'>

# %% [markdown]
# __2. Using group by method__

# %%
df = data.groupby("Release Date")["Category"].count().reset_index()
df1 = df.sort_values('Category',ascending=False)
ans = max(df["Category"])
year = df[df["Category"]==ans]["Release Date"]
year = int(year.iloc[0])
print(f"The heighest no of TV show and movies is {ans} were relesed in {year}")
# Out:
# The heighest no of TV show and movies is 971 were relesed in 2019

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize =(15, 7))
ax = sns.barplot(df, x=df["Release Date"],y=df["Category"],width = 0.8)
ax.tick_params(axis='x', labelrotation=90)

# %% [markdown]
# __Q-3. How many TV show and movies in this datasets ? show with bar graph__

# %% [markdown]
# __1.Using groupby() function__

# %%
data.groupby("Category").Category.count()
# Out:
# Category
# Movie      3867
# TV Show    2100
# Name: Category, dtype: int64

# %%
gb = data.groupby("Category").Category.count().plot(kind="bar").tick_params(axis='x', labelrotation=0)

# %% [markdown]
# __2. Using countplot__

# %%
sns.countplot(data,x = "Category" )
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# __Q-4 Show all the movies that were release in 2000__

# %% [markdown]
# __Filtering__

# %%
data[(data["Release Date"]==2000.0) & (data["Category"]=="Movie")]
# Out:
#      Show_id                                   Title  \
# 562     s563                       Battlefield Earth
# 940     s941                        Charlie's Angels
# 1652   s1653                                    Fiza
# 2417   s2418                  Joseph: King of Dreams
# 3176   s3177  Monty Python: Before the Flying Circus
# 3689   s3690             Phir Bhi Dil Hai Hindustani
# 4022   s4023             Rugrats in Paris: The Movie
# 4317   s4318                                Snow Day
# 5110   s5111                             The Patriot
# 5305   s5306                    The Whole Nine Yards
#
#                                             Description  \
# 562   In the year 3000, an alien race known as the P...
# 940   A tight-knit trio of specially trained agents ...
# 1652  Fiza's brother disappears during Mumbai's horr...
# 2417  With his gift of dream interpretation and his ...
# 3176  Discover how six seemingly ordinary but suprem...
# ...

# %% [markdown]
# __Q-5 Show all the titles of TV show that are released INDIA only__

# %%
data[(data["Country"]=="India") & (data["Category"]=="TV Show")]["Title"]
# Out:
# 245                                      Akbar Birbal
# 302                                      Alma Matters
# 510                       Bad Boy Billionaires: India
# 551                                     Bard of Blood
# 622                                            Betaal
# 642                                Bhaag Beanie Bhaag
# 758                                     Bombay Begums
# 1005    ChuChu TV Nursery Rhymes & Kids Songs (Hindi)
# 1071                                  College Romance
# 1130                    Cricket Fever: Mumbai Indians
# 1256                                      Delhi Crime
# 1500                                Engineering Girls
# 1555                Fabulous Lives of Bollywood Wives
# 1807                                            GHOUL
# 1827                                     Girls Hostel
# 1981                                          Hasmukh
# 2250                                          Inmates
# ...

# %% [markdown]
# __Q-6 Show top 10 directors who give heighest no of TV show and movies to netflix__

# %% [markdown]
# __1. Using Groupby()__

# %%
dir = data.groupby("Director").agg(show = ("Category","count")).reset_index().sort_values("show",ascending=False).head(10)
dir
# Out:
#                     Director  show
# 2245  Raúl Campos, Jan Suter    18
# 1675            Marcus Raboy    16
# 2653             Suhas Kadav    15
# 1151               Jay Karas    14
# 432      Cathy Garcia-Molina    12
# 2957         Youssef Chahine    12
# 1149             Jay Chapman    11
# 815          Fernando Ayllón     8
# 1501             Lance Bangs     8
# 2388             Ryan Polito     8

# %% [markdown]
# __2. Using value_counts() function__

# %%
data["Director"].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               15
# Jay Karas                 14
# Youssef Chahine           12
# Cathy Garcia-Molina       12
# Jay Chapman               11
# Lance Bangs                8
# Don Michael Paul           8
# Fernando Ayllón            8
# Name: count, dtype: int64

# %%
data["Director"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Director'>

# %% [markdown]
# __Q-7 show all the records where "Category is movie and type is comedy" or "country is United state"__

# %%
data.head(2)
# Out:
#   Show_id     Title                                        Description  \
# 0      s1  (Un)Well  This docuseries takes a deep dive into the luc...
# 1      s2    #Alive  As a grisly virus rampages a city, a lone man ...
#
#   Director                                            Type  \
# 0      NaN                                      Reality TV
# 1   Cho Il  Horror Movies, International Movies, Thrillers
#
#                        Cast        Country  Release Date Rating  Duration  \
# 0                       NaN  United States        2020.0  TV-MA  1 Season
# 1  Yoo Ah-in, Park Shin-hye    South Korea        2020.0  TV-MA    99 min
#
#   Category         Date Added
# 0  TV Show                NaN
# 1    Movie  September 8, 2020

# %%
data[(((data["Category"]=="Movie") & (data["Type"]=="Comedies")) | (data["Country"]=="United Kingdom"))]
# Out:
#      Show_id                                   Title  \
# 7         s8                            #realityhigh
# 37       s38                                21 Again
# 106     s107             A Futile and Stupid Gesture
# 111     s112  A Grand Night In: The Story of Aardman
# 121     s122                          A Little Chaos
# ...      ...                                     ...
# 5868   s5869                                 Work It
# 5875   s5876                  World War II in Colour
# 5889   s5890                  XV: Beyond the Tryline
# 5918   s5919                         Young Wallander
# 5942   s5943                              Zero Chill
#
#                                             Description          Director  \
# 7     When nerdy high schooler Dani finally attracts...  Fernando Lebrija
# 37    In a social experiment, a group of daughters s...               NaN
# 106   In a brief life full of triumph and failure, "...        David Wain
# ...

# %% [markdown]
# __Q-8 In how many movies/shows ,Tom cruise was cast__

# %%
data[data['Cast']=="Tom Cruise"]
# Out:
# Empty DataFrame
# Columns: [Show_id, Title, Description, Director, Type, Cast, Country, Release Date, Rating, Duration, Category, Date Added]
# Index: []

# %%
data_new=data.dropna()
data_new[data_new['Cast'].str.contains('Tom Cruise')]   # this function is not work on null value
# Out:
#      Show_id     Title                                        Description  \
# 3838   s3839  Rain Man  Motivated by money, a selfish workaholic seeki...
#
#             Director                    Type  \
# 3838  Barry Levinson  Classic Movies, Dramas
#
#                                                    Cast        Country  \
# 3838  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#       Release Date Rating Duration Category     Date Added
# 3838        1988.0      R  134 min    Movie  March 1, 2021

# %% [markdown]
# __Q-9 what are the different rating difined by the netflix__

# %%
data.Rating.nunique()   #show total no of unique value
data.Rating.unique()     # show all the unique value
# Out:
# array(['TV-MA', 'TV-14', 'TV-G', 'TV-PG', 'TV-Y', 'R', 'PG-13', 'TV-Y7',
#        'PG', 'G', nan, 'NC-17'], dtype=object)

# %% [markdown]
# __Q-10 How many movies got TV-14 in Canada__

# %%
data[(((data["Category"]=="Movie") & (data["Country"] == "Canada") & (data["Rating"] == "TV-14")))]
# Out:
#      Show_id                                        Title  \
# 4         s5                             #cats_the_mewvie
# 2895   s2896   Made You Look: A True Story About Fake Art
# 2980   s2981  Martin Matte: La vie, la mort...eh la la..!
# 5344   s5345               There's Something in the Water
#
#                                             Description  \
# 4     This pawesome documentary explores how our fel...
# 2895  A woman walks into a New York gallery with a c...
# 2980  Quebecois comedy star Martin Matte serves up e...
# 5344  This documentary spotlights the struggle of mi...
#
#                     Director                                 Type  \
# 4           Michael Margolis  Documentaries, International Movies
# 2895            Barry Avrich  Documentaries, International Movies
# 2980     Jean-François Blais                      Stand-Up Comedy
# 5344  Ellen Page, Ian Daniel  Documentaries, International Movies
#
# ...

# %%
data[(((data["Category"]=="Movie") & (data["Country"] == "Canada") & (data["Rating"] == "TV-14")))].shape
# Out:
# (4, 12)

# %% [markdown]
# __Q-11 How many TV Show got R rating after 2018__

# %%
data[(((data["Rating"]=="R") & (data["Category"]=="TV Show")) & (data["Release Date"]>2018))]
# Out:
# Empty DataFrame
# Columns: [Show_id, Title, Description, Director, Type, Cast, Country, Release Date, Rating, Duration, Category, Date Added]
# Index: []

# %% [markdown]
# __Q-12 What is the maximum duration of movie/show on netflix (ignore season date)__

# %% [markdown]
# __1.str.split() for saparate numeric and string data__

# %%
data[['minute','unit']] = data['Duration'].str.split(" ",expand=True)
s_data=data.sort_values("minute",ascending=False)
s_data.head(1)
# Out:
#   Show_id   Title                                        Description Director  \
# 1      s2  #Alive  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                              Type                      Cast  \
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#        Country  Release Date Rating Duration Category         Date Added  \
# 1  South Korea        2020.0  TV-MA   99 min    Movie  September 8, 2020
#
#   minute unit
# 1     99  min

# %% [markdown]
# __Q-13 which individual country which has maximum no of TV shows__

# %%
data_tvShow = data[data['Category']=='TV Show']
data_tvShow['Country'].value_counts().head(1)
# Out:
# Country
# United States    624
# Name: count, dtype: int64
